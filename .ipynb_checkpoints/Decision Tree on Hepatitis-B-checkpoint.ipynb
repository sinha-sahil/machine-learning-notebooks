# %% [markdown]
# <div style="background: linear-gradient(to bottom, #200122, #6f0000); border: 2px; box-radius: 20px"><h1 style="color: white; text-align: center"><br> Hepatitis B<br></h1></div>

# %% [markdown]
# <p style="font-size: 22px"><b>Aim</b> : To implement Decision Tree with the given dataset of Hepatitis B </p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Building Feature Set

# %% [markdown]
# <p style="font-size: 22px"><b>About Data</b></p>
# <p>This dataset contains details about 155 Humans and their condition related to Hepatitis B</p>
# <p>Total No of Attributes are : 20 </p>
# <p>Details of Attributes are as follows</p>
# <ul>
#     <li> Class: DIE, LIVE </li>
#     <li> AGE: 10, 20, 30, 40, 50, 60, 70, 80 </li>
#     <li> SEX: male, female </li>
#     <li> STEROID: no, yes</li>
#     <li> ANTIVIRALS: no, yes</li>
#     <li> FATIGUE: no, yes</li>
#     <li> MALAISE: no, yes</li>
#     <li> ANOREXIA: no, yes</li>
#     <li> LIVER BIG: no, yes</li>
#     <li> LIVER FIRM: no, yes</li>
#     <li> SPLEEN PALPABLE: no, yes</li>
#     <li> SPIDERS: no, yes</li>
#     <li> ASCITES: no, yes</li>
#     <li> VARICES: no, yes</li>
#     <li> BILIRUBIN: 0.39, 0.80, 1.20, 2.00, 3.00, 4.00</li>
#     <li> ALK PHOSPHATE: 33, 80, 120, 160, 200, 250</li>
#     <li> SGOT: 13, 100, 200, 300, 400, 500</li>
#     <li> ALBUMIN: 2.1, 3.0, 3.8, 4.5, 5.0, 6.0</li>
#     <li> PROTIME: 10, 20, 30, 40, 50, 60, 70, 80, 90</li>
#     <li>  HISTOLOGY: no, yes</li>
# </ul>

# %% [markdown]
# <p style="font-size: 22px"><b>Reading Data</b></p>

# %%
hep_data = pd.read_csv('./Datasets/hepatitis.data')
hep_data
# Out:
#      Class  Age  Sex Streoid  Antivirals Fatigue Malaise Anorexia LiverBig  \
# 0        2   30    2       1           2       2       2        2        1
# 1        2   50    1       1           2       1       2        2        1
# 2        2   78    1       2           2       1       2        2        2
# 3        2   31    1       ?           1       2       2        2        2
# 4        2   34    1       2           2       2       2        2        2
# 5        2   34    1       2           2       2       2        2        2
# 6        1   51    1       1           2       1       2        1        2
# 7        2   23    1       2           2       2       2        2        2
# 8        2   39    1       2           2       1       2        2        2
# 9        2   30    1       2           2       2       2        2        2
# 10       2   39    1       1           1       2       2        2        1
# 11       2   32    1       2           1       1       2        2        2
# 12       2   41    1       2           1       1       2        2        2
# 13       2   30    1       2           2       1       2        2        2
# 14       2   47    1       1           1       2       2        2        2
# 15       2   38    1       1           2       1       1        1        2
# 16       2   66    1       2           2       1       2        2        2
# 17       2   40    1       1           2       1       2        2        2
# 18       2   38    1       2           2       2       2        2        2
# 19       2   38    1       1           1       2       2        2        1
# 20       2   22    2       2           1       1       2        2        2
# 21       2   27    1       2           2       1       1        1        1
# 22       2   31    1       2           2       2       2        2        2
# 23       2   42    1       2           2       2       2        2        2
# 24       2   25    2       1           1       2       2        2        2
# 25       2   27    1       1           2       1       1        2        2
# 26       2   49    1       1           1       1       1        1        2
# 27       2   58    2       2           2       1       2        2        2
# 28       2   61    1       1           2       1       2        2        1
# 29       2   51    1       1           1       1       1        2        2
# ..     ...  ...  ...     ...         ...     ...     ...      ...      ...
# 125      2   34    2       2           2       1       1        1        1
# 142         1              1       1       2       1      1.00           ?
# 143         2              1       1       2       2      1.40          85
# 144         2              2       1       1       2      1.90           ?
# 145         2              2       2       2       2      1.20          75
# 146         1              1       1       2       1      4.20          65
# 147         ?              ?       ?       ?       ?      1.70         109
# 148         ?              2       2       2       2      0.90          89
# 149         2              2       2       2       2      0.60         120
# 150         2              2       1       1       1      7.60           ?
# 151         1              2       2       2       2      0.90         126
# 152         1              2       1       2       2      0.80          75
# 153         2              1       1       2       1      1.50          81
# 154         2              1       1       1       2      1.20         100
#
#     SGOT Albumin Protime  Histology
# 0     18     4.0       ?          1
# 1     42     3.5       ?          1
# 2     32     4.0       ?          1
# 3     52     4.0      80          1
# 4    200     4.0       ?          1
# 5     28     4.0      75          1
# 6      ?       ?       ?          1
# 7      ?       ?       ?          1
# 8     48     4.4       ?          1
# 9    120     3.9       ?          1
# 10    30     4.4      85          1
# 11   249     3.7      54          1
# 12    60     3.9      52          1
# 13   144     4.9      78          1
# 14    60       ?       ?          1
# 15    89     2.9      46          1
# 16    53     4.3       ?          1
# 17   166     4.0      63          1
# 18    42     4.1      85          2
# 19    28     4.2      62          1
# 20    20     4.2      64          1
# 21    98     4.1      39          1
# 22    20     4.0     100          1
# 23    63     4.7      47          1
# 24    18     4.3      70          1
# 25    46     3.8     100          1
# 26    48     3.7       ?          1
# 27    55     2.7      36          1
# 28    25     3.8     100          1
# 29    58     4.6      52          1
# ..   ...     ...     ...        ...
# 125   24     4.1     100          2
# 126   20     4.0       ?          2
# 127   75     2.4      32          2
# 128   92     3.1      66          2
# 129   55     3.3      30          2
# 130   30     4.5       0          2
# 131  101     2.2       ?          2
# 132  278     3.8       ?          2
# 133   52     3.4      50          2
# 134   49     3.8      90          2
# 135  181     4.5      57          2
# 136   33     4.5       ?          2
# 137  140     3.5      56          2
# 138   30     2.6      31          2
# 139   44     4.2      85          2
# 140   60     2.7       ?          2
# 141   28     3.5      43          2
# 142   20     3.0      63          2
# 143   70     3.5      35          2
# 144  114     2.4       ?          2
# 145  173     4.2      54          2
# 146  120     3.4       ?          2
# 147  528     2.8      35          2
# 148  152     4.0       ?          2
# 149   30     4.0       ?          2
# 150  242     3.3      50          2
# 151  142     4.3       ?          2
# 152   20     4.1       ?          2
# 153   19     4.1      48          2
# 154   19     3.1      42          2
#
# [155 rows x 20 columns]

# %% [markdown]
# <p style="font-size: 22px"><b>Analyzing Data</b></p>

# %%
hep_data.describe(include='all')
# Out:
#              Class         Age         Sex Streoid  Antivirals Fatigue  \
# count   155.000000  155.000000  155.000000     155  155.000000     155
# unique         NaN         NaN         NaN       3         NaN       3
# top            NaN         NaN         NaN       2         NaN       1
# freq           NaN         NaN         NaN      78         NaN     100
# mean      1.793548   41.200000    1.103226     NaN    1.845161     NaN
# std       0.406070   12.565878    0.305240     NaN    0.362923     NaN
# min       1.000000    7.000000    1.000000     NaN    1.000000     NaN
# 25%       2.000000   32.000000    1.000000     NaN    2.000000     NaN
# 50%       2.000000   39.000000    1.000000     NaN    2.000000     NaN
# 75%       2.000000   50.000000    1.000000     NaN    2.000000     NaN
# max       2.000000   78.000000    2.000000     NaN    2.000000     NaN
#
#        Malaise Anorexia LiverBig LiverFirm SpleenPalpable Spiders Ascites  \
# count      155      155      155       155            155     155     155
# unique       3        3        3         3              3       3       3
# top          2        2        2         2              2       2       2
# freq        93      122      120        84            120      99     130
# mean       NaN      NaN      NaN       NaN            NaN     NaN     NaN
# std        NaN      NaN      NaN       NaN            NaN     NaN     NaN
# min        NaN      NaN      NaN       NaN            NaN     NaN     NaN
# 25%        NaN      NaN      NaN       NaN            NaN     NaN     NaN
# 50%        NaN      NaN      NaN       NaN            NaN     NaN     NaN
# 75%        NaN      NaN      NaN       NaN            NaN     NaN     NaN
# max        NaN      NaN      NaN       NaN            NaN     NaN     NaN
#
#        Varices Bilirubin AlkPhospate SGOT Albumin Protime   Histology
# count      155       155         155  155     155     155  155.000000
# unique       3        35          84   85      30      45         NaN
# top          2      1.00           ?   20     4.0       ?         NaN
# freq       132        29          29    7      25      67         NaN
# mean       NaN       NaN         NaN  NaN     NaN     NaN    1.451613
# std        NaN       NaN         NaN  NaN     NaN     NaN    0.499266
# min        NaN       NaN         NaN  NaN     NaN     NaN    1.000000
# 25%        NaN       NaN         NaN  NaN     NaN     NaN    1.000000
# 50%        NaN       NaN         NaN  NaN     NaN     NaN    1.000000
# 75%        NaN       NaN         NaN  NaN     NaN     NaN    2.000000
# max        NaN       NaN         NaN  NaN     NaN     NaN    2.000000

# %% [markdown]
# <p style="font-size: 20px;"> Entries where data is missing </p>

# %%
hep_missing = hep_data.loc[(hep_data['Bilirubin']=='?') | (hep_data['AlkPhospate']=='?') | (hep_data['SGOT']=='?') | (hep_data['Albumin']=='?') | (hep_data['Protime']=='?')]

# %%
hep_missing.iloc[:, 14:].describe()
# Out:
#        Histology
# count  72.000000
# mean    1.486111
# std     0.503315
# min     1.000000
# 25%     1.000000
# 50%     1.000000
# 75%     2.000000
# max     2.000000

# %% [markdown]
# <p style="font-size: 20px">Data of Alive Persons</p>

# %%
hep_data.loc[hep_data['Class']==2].describe()
# Out:
#        Class         Age         Sex  Antivirals   Histology
# count  123.0  123.000000  123.000000  123.000000  123.000000
# mean     2.0   39.796748    1.130081    1.821138    1.365854
# std      0.0   12.828605    0.337769    0.384804    0.483639
# min      2.0    7.000000    1.000000    1.000000    1.000000
# 25%      2.0   30.000000    1.000000    2.000000    1.000000
# 50%      2.0   38.000000    1.000000    2.000000    1.000000
# 75%      2.0   50.000000    1.000000    2.000000    2.000000
# max      2.0   78.000000    2.000000    2.000000    2.000000

# %% [markdown]
# <p style="font-size: 20px; "> Data of Dead Persons</p>

# %%
hep_data.loc[hep_data['Class']==1].describe()
# Out:
#        Class        Age   Sex  Antivirals  Histology
# count   32.0  32.000000  32.0   32.000000  32.000000
# mean     1.0  46.593750   1.0    1.937500   1.781250
# std      0.0   9.944554   0.0    0.245935   0.420013
# min      1.0  30.000000   1.0    1.000000   1.000000
# 25%      1.0  38.750000   1.0    2.000000   2.000000
# 50%      1.0  46.500000   1.0    2.000000   2.000000
# 75%      1.0  54.500000   1.0    2.000000   2.000000
# max      1.0  70.000000   1.0    2.000000   2.000000

# %% [markdown]
# # Creating Train and Test splits

# %%
X_train, X_test, y_train, y_test =  train_test_split(hep_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-97eb85276ea5> in <module>()
# ----> 1 X_train, X_test, y_train, y_test =  train_test_split(hep_data)
#
# ValueError: not enough values to unpack (expected 4, got 2)
